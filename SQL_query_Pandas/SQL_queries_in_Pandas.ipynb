# %% [markdown]
# ### This Jupyter notebook includes the codes showed in https://codeburst.io/how-to-rewrite-your-sql-queries-in-pandas-and-more-149d341fc53e

# %% [markdown]
# ### Import all data

# %%
import pandas as pd

# %%
airports = pd.read_csv('airports.csv')
airport_freq = pd.read_csv('airport-frequencies.csv')
runways = pd.read_csv('runways.csv')

# %%
airports.head()
# Out:
#        id ident           type                                name  \
# 0    6523   00A       heliport                   Total Rf Heliport
# 1  323361  00AA  small_airport                Aero B Ranch Airport
# 2    6524  00AK  small_airport                        Lowell Field
# 3    6525  00AL  small_airport                        Epps Airpark
# 4    6526  00AR         closed  Newport Hospital & Clinic Heliport
#
#    latitude_deg  longitude_deg  elevation_ft continent iso_country iso_region  \
# 0     40.070801     -74.933601          11.0       NaN          US      US-PA
# 1     38.704022    -101.473911        3435.0       NaN          US      US-KS
# 2     59.949200    -151.695999         450.0       NaN          US      US-AK
# 3     34.864799     -86.770302         820.0       NaN          US      US-AL
# 4     35.608700     -91.254898         237.0       NaN          US      US-AR
#
#    municipality scheduled_service gps_code iata_code local_code home_link  \
# 0      Bensalem                no      00A       NaN        00A       NaN
# 1         Leoti                no     00AA       NaN       00AA       NaN
# 2  Anchor Point                no     00AK       NaN       00AK       NaN
# 3       Harvest                no     00AL       NaN       00AL       NaN
# 4       Newport                no      NaN       NaN        NaN       NaN
#
#   wikipedia_link keywords
# 0            NaN      NaN
# 1            NaN      NaN
# 2            NaN      NaN
# 3            NaN      NaN
# 4            NaN     00AR

# %%
airports.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53631 entries, 0 to 53630
# Data columns (total 18 columns):
# id                   53631 non-null int64
# ident                53631 non-null object
# type                 53631 non-null object
# name                 53631 non-null object
# latitude_deg         53631 non-null float64
# longitude_deg        53631 non-null float64
# elevation_ft         47257 non-null float64
# continent            26563 non-null object
# iso_country          53384 non-null object
# iso_region           53631 non-null object
# municipality         48068 non-null object
# scheduled_service    53631 non-null object
# gps_code             41117 non-null object
# iata_code            9159 non-null object
# local_code           28318 non-null object
# home_link            2894 non-null object
# wikipedia_link       9619 non-null object
# keywords             8004 non-null object
# dtypes: float64(3), int64(1), object(14)
# memory usage: 7.4+ MB

# %%
airport_freq.head()
# Out:
#        id  airport_ref airport_ident   type          description  \
# 0   70518         6528          00CA   CTAF                 CTAF
# 1  307581         6589          01FL  ARCAL                  NaN
# 2   75239         6589          01FL   CTAF  CEDAR KNOLL TRAFFIC
# 3   60191         6756          04CA   CTAF                 CTAF
# 4   59287         6779          04MS   UNIC               UNICOM
#
#    frequency_mhz
# 0          122.9
# 1          122.9
# 2          122.8
# 3          122.9
# 4          122.8

# %%
airport_freq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28647 entries, 0 to 28646
# Data columns (total 6 columns):
# id               28647 non-null int64
# airport_ref      28647 non-null int64
# airport_ident    28647 non-null object
# type             28647 non-null object
# description      27923 non-null object
# frequency_mhz    28647 non-null float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 1.3+ MB

# %%
runways.head()
# Out:
#        id  airport_ref airport_ident  length_ft  width_ft surface  lighted  \
# 0  269408         6523           00A       80.0      80.0  ASPH-G        1
# 1  255155         6524          00AK     2500.0      70.0    GRVL        0
# 2  254165         6525          00AL     2300.0     200.0    TURF        0
# 3  270932         6526          00AR       40.0      40.0   GRASS        0
# 4  322128       322127          00AS     1450.0      60.0    Turf        0
#
#    closed le_ident  le_latitude_deg     ...       le_elevation_ft  \
# 0       0       H1              NaN     ...                   NaN
# 1       0        N              NaN     ...                   NaN
# 2       0       01              NaN     ...                   NaN
# 3       0       H1              NaN     ...                   NaN
# 4       0        1              NaN     ...                   NaN
#
#    le_heading_degT  le_displaced_threshold_ft  he_ident he_latitude_deg  \
# 0              NaN                        NaN       NaN             NaN
# 1              NaN                        NaN         S             NaN
# 2              NaN                        NaN        19             NaN
# 3              NaN                        NaN        H1             NaN
# 4              NaN                        NaN        19             NaN
#
#    he_longitude_deg  he_elevation_ft  he_heading_degT  \
# 0               NaN              NaN              NaN
# 1               NaN              NaN              NaN
# 2               NaN              NaN              NaN
# 3               NaN              NaN              NaN
# 4               NaN              NaN              NaN
#
#    he_displaced_threshold_ft  Unnamed: 20
# 0                        NaN          NaN
# 1                        NaN          NaN
# 2                        NaN          NaN
# 3                        NaN          NaN
# 4                        NaN          NaN
#
# [5 rows x 21 columns]

# %%
runways.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40746 entries, 0 to 40745
# Data columns (total 21 columns):
# id                           40746 non-null int64
# airport_ref                  40746 non-null int64
# airport_ident                40746 non-null object
# length_ft                    40576 non-null float64
# width_ft                     38142 non-null float64
# surface                      40523 non-null object
# lighted                      40746 non-null int64
# closed                       40746 non-null int64
# le_ident                     40627 non-null object
# le_latitude_deg              14218 non-null float64
# le_longitude_deg             14215 non-null float64
# le_elevation_ft              12090 non-null float64
# le_heading_degT              14021 non-null float64
# le_displaced_threshold_ft    2796 non-null float64
# he_ident                     34604 non-null object
# he_latitude_deg              14205 non-null float64
# he_longitude_deg             14207 non-null float64
# he_elevation_ft              11980 non-null float64
# he_heading_degT              15834 non-null float64
# he_displaced_threshold_ft    3105 non-null float64
# Unnamed: 20                  0 non-null float64
# dtypes: float64(13), int64(4), object(4)
# memory usage: 6.5+ MB

# %% [markdown]
# ## SELECT, WHERE, DISTINCT, LIMIT

# %% [markdown]
# ### SQL:
# select * from airports limit 3

# %%
airports.head(3)
# Out:
#        id ident           type                  name  latitude_deg  \
# 0    6523   00A       heliport     Total Rf Heliport     40.070801
# 1  323361  00AA  small_airport  Aero B Ranch Airport     38.704022
# 2    6524  00AK  small_airport          Lowell Field     59.949200
#
#    longitude_deg  elevation_ft continent iso_country iso_region  municipality  \
# 0     -74.933601          11.0       NaN          US      US-PA      Bensalem
# 1    -101.473911        3435.0       NaN          US      US-KS         Leoti
# 2    -151.695999         450.0       NaN          US      US-AK  Anchor Point
#
#   scheduled_service gps_code iata_code local_code home_link wikipedia_link  \
# 0                no      00A       NaN        00A       NaN            NaN
# 1                no     00AA       NaN       00AA       NaN            NaN
# 2                no     00AK       NaN       00AK       NaN            NaN
#
#   keywords
# 0      NaN
# 1      NaN
# 2      NaN

# %% [markdown]
# ### SQL:
# select id from airports where ident = 'KLAX'

# %%
airports.loc[airports.ident == 'KLAX', :]
# Out:
#          id ident           type                               name  \
# 27524  3632  KLAX  large_airport  Los Angeles International Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 27524     33.942501    -118.407997         125.0       NaN          US
#
#       iso_region municipality scheduled_service gps_code iata_code local_code  \
# 27524      US-CA  Los Angeles               yes     KLAX       LAX        LAX
#
#                      home_link  \
# 27524  http://www.iflylax.com/
#
#                                           wikipedia_link keywords
# 27524  http://en.wikipedia.org/wiki/Los_Angeles_Inter...      NaN

# %%
airports[airports.ident == 'KLAX'].id
# Out:
# 27524    3632
# Name: id, dtype: int64

# %% [markdown]
# ### SQL:
# select distinct type from airport

# %%
airports.type.unique()
# Out:
# array(['heliport', 'small_airport', 'closed', 'seaplane_base',
#        'balloonport', 'medium_airport', 'large_airport'], dtype=object)

# %% [markdown]
# #
#
#
#
#
#
#
#
#
# ## SELECT with multiple conditions

# %% [markdown]
# ### SQL:
# select * from airports where iso_region = 'US-CA' and type = 'seaplane_base'

# %%
airports[(airports.iso_region == 'US-CA') & (airports.type == 'seaplane_base')]
# Out:
#            id ident           type                                      name  \
# 972      7436   0O0  seaplane_base          San Luis Reservoir Seaplane Base
# 2480     8877  22CA  seaplane_base            Commodore Center Seaplane Base
# 6215    12298  5CA9  seaplane_base       Konocti  - Clear Lake Seaplane Base
# 12763   16514   C39  seaplane_base                 Folsom Lake Seaplane Base
# 15077   16830  CN20  seaplane_base             Ferndale Resort Seaplane Base
# 17428   17157   E20  seaplane_base              Lake Berryessa Seaplane Base
# 22526   17613   H77  seaplane_base           Bridge Bay Resort Seaplane Base
# 29766   21444   L11  seaplane_base                Pebbly Beach Seaplane Base
# 35928   23479   O06  seaplane_base  Lake Oroville Landing Area Seaplane Base
# 39550   24384   S74  seaplane_base                   Lost Isle Seaplane Base
# 46947  300312   TWH  seaplane_base           Two Harbors Amphibious Terminal
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 972       37.058300    -121.125999         544.0       NaN          US
# 2480      37.879902    -122.514000           NaN       NaN          US
# 6215      38.977699    -122.718002        1326.0       NaN          US
# 12763     38.707199    -121.133003         466.0       NaN          US
# 15077     39.002998    -122.796997        1326.0       NaN          US
# 17428     38.591599    -122.259003         440.0       NaN          US
# 22526     40.757599    -122.322998        1065.0       NaN          US
# 29766     33.338402    -118.311996           NaN       NaN          US
# 35928     39.566601    -121.468002         900.0       NaN          US
# 39550     38.004101    -121.457001           NaN       NaN          US
# 46947     33.432222    -118.508611           NaN       NaN          US
#
#       iso_region municipality scheduled_service gps_code iata_code local_code  \
# 972        US-CA    Los Banos                no      0O0       NaN        0O0
# 2480       US-CA    Sausalito                no     22CA       NaN       22CA
# 6215       US-CA  Kelseyville                no     5CA9       NaN       5CA9
# 12763      US-CA       Folsom                no      C39       NaN        C39
# 15077      US-CA  Kelseyville                no     CN20       NaN       CN20
# 17428      US-CA         Napa                no      E20       NaN        E20
# 22526      US-CA      Redding                no      H77       NaN        H77
# 29766      US-CA       Avalon                no     KL11       NaN        L11
# 35928      US-CA     Oroville                no      O06       NaN        O06
# 39550      US-CA     Stockton                no      S74       NaN        S74
# 46947      US-CA  Two Harbors                no      NaN       TWH        NaN
#
#       home_link wikipedia_link keywords
# 972         NaN            NaN      NaN
# 2480        NaN            NaN      NaN
# 6215        NaN            NaN      NaN
# 12763       NaN            NaN      NaN
# 15077       NaN            NaN      NaN
# 17428       NaN            NaN      NaN
# 22526       NaN            NaN      NaN
# 29766       NaN            NaN      NaN
# 35928       NaN            NaN      NaN
# 39550       NaN            NaN      NaN
# 46947       NaN            NaN      NaN

# %% [markdown]
# ### SQL:
# select ident, name, municipality from airports where iso_region = 'US-CA' and type = 'large_airport'

# %%
airports[(airports.iso_region == 'US-CA') & (airports.type == 'large_airport')].loc[:, ['ident', 'name', 'municipality']]
# Out:
#       ident                                             name   municipality
# 25897  KBAB                             Beale Air Force Base     Marysville
# 26734  KEDW                           Edwards Air Force Base        Edwards
# 27524  KLAX                Los Angeles International Airport    Los Angeles
# 28051  KOAK       Metropolitan Oakland International Airport        Oakland
# 28107  KONT                    Ontario International Airport        Ontario
# 29134  KSAN                  San Diego International Airport      San Diego
# 29174  KSFO              San Francisco International Airport  San Francisco
# 29195  KSJC  Norman Y. Mineta San Jose International Airport       San Jose
# 29217  KSMF                 Sacramento International Airport     Sacramento
# 29223  KSNA         John Wayne Airport-Orange County Airport      Santa Ana
# 29272  KSUU                            Travis Air Force Base      Fairfield
# 29504  KVBG                        Vandenberg Air Force Base         Lompoc

# %% [markdown]
# ##
# ##
# ## ORDER BY

# %% [markdown]
# ### SQL:
# select * from airport_freq where airport_ident = 'KLAX' order by type

# %%
airport_freq[airport_freq.airport_ident == 'KLAX'].sort_values('type')
# Out:
#           id  airport_ref airport_ident  type description  frequency_mhz
# 11862  60767         3632          KLAX   APP   SOCAL APP          36.07
# 11863  60766         3632          KLAX   APP   SOCAL APP         124.30
# 11864  60768         3632          KLAX  ATIS        ATIS         133.80
# 11865  60769         3632          KLAX   CLD    CLNC DEL         121.40
# 11866  60770         3632          KLAX   DEP   SOCAL DEP         124.30
# 11867  60771         3632          KLAX   GND         GND         121.65
# 11868  60772         3632          KLAX  MISC          CG          34.50
# 11869  60773         3632          KLAX  MISC          CG         898.40
# 11870  60774         3632          KLAX   OPS          AF          37.22
# 11871  60775         3632          KLAX   TWR         TWR         119.80
# 11872  60776         3632          KLAX  UNIC      UNICOM         122.95

# %% [markdown]
# ### SQL:
# select * from airport_freq where airport_ident = 'KLAX' order by type desc

# %%
airport_freq[airport_freq.airport_ident == 'KLAX'].sort_values('type', ascending=False)
# Out:
#           id  airport_ref airport_ident  type description  frequency_mhz
# 11872  60776         3632          KLAX  UNIC      UNICOM         122.95
# 11871  60775         3632          KLAX   TWR         TWR         119.80
# 11870  60774         3632          KLAX   OPS          AF          37.22
# 11868  60772         3632          KLAX  MISC          CG          34.50
# 11869  60773         3632          KLAX  MISC          CG         898.40
# 11867  60771         3632          KLAX   GND         GND         121.65
# 11866  60770         3632          KLAX   DEP   SOCAL DEP         124.30
# 11865  60769         3632          KLAX   CLD    CLNC DEL         121.40
# 11864  60768         3632          KLAX  ATIS        ATIS         133.80
# 11862  60767         3632          KLAX   APP   SOCAL APP          36.07
# 11863  60766         3632          KLAX   APP   SOCAL APP         124.30

# %% [markdown]
# ##
#
#
# ##
#
# ## IN… NOT IN

# %% [markdown]
# ### SQL:
# select * from airports where type in ('heliport', 'balloonport')

# %%
airports[airports.type.isin(['heliport', 'balloonport'])]
# Out:
#            id    ident      type  \
# 0        6523      00A  heliport
# 9      322658     00CN  heliport
# 12       6532     00FD  heliport
# 15       6535     00GE  heliport
# 16       6536     00HI  heliport
# 19       6538     00II  heliport
# 21       6540     00IN  heliport
# 25      45437     00LA  heliport
# 26       6544     00LL  heliport
# 29       6547     00MI  heliport
# 35       6553     00NJ  heliport
# 39       6556     00OI  heliport
# 40       6557     00OR  heliport
# 41       6558     00PA  heliport
# 46       6562     00TA  heliport
# 47       6563     00TE  heliport
# 59     322300     00WY  heliport
# 62       6577     01AK  heliport
# 64       6579     01AR  heliport
# 65       6580     01AZ  heliport
# 67       6582     01CA  heliport
# 69       6584     01CN  heliport
# 70       6585     01CO  heliport
# 71       6586     01CT  heliport
# 73       6588     01FD  heliport
# 75       6590     01GA  heliport
# 80       6594     01IL  heliport
# 81       6595     01IN  heliport
# 86       6600     01KY  heliport
# 90       6604     01MA  heliport
# ...       ...      ...       ...
# 53051  309395     YXPK  heliport
# 53052  309376     YXPM  heliport
# 53053  309316     YXPN  heliport
# 53054  309375     YXQU  heliport
# 53055  309374     YXRN  heliport
# 53056  309342     YXSA  heliport
# 53057  309353     YXSC  heliport
# 53058  309344     YXSG  heliport
# 53059  309352     YXSH  heliport
# 53060  309351     YXSI  heliport
# 53061  309343     YXSU  heliport
# 53063  310102     YXTE  heliport
# 53064  313356     YXTN  heliport
# 53065  310101     YXTR  heliport
# 53066  309333     YXTT  heliport
# 53067  309334     YXTW  heliport
# 53068  317136     YXUH  heliport
# 53069  310103     YXWG  heliport
# 53070  309327     YXWL  heliport
# 53071  311184     YXWT  heliport
# 53072  310104     YXWW  heliport
# 53073  309326     YXWY  heliport
# 53074  309325     YXYO  heliport
# 53083   28091     YYBK  heliport
# 53161   41544  ZA-0021  heliport
# 53257  312611  ZA-0117  heliport
# 53259  312624  ZA-0119  heliport
# 53280  318475  ZA-0140  heliport
# 53370  301278      ZIZ  heliport
# 53628   46378  ZZ-0001  heliport
#
#                                                    name  latitude_deg  \
# 0                                     Total Rf Heliport     40.070801
# 9                       Kitchen Creek Helibase Heliport     32.727374
# 12                                   Ringhaver Heliport     28.846600
# 15                                     Caffrey Heliport     33.884201
# 16                                   Kaupulehu Heliport     19.832715
# 19                   Bailey Generation Station Heliport     41.644501
# 21                      St Mary Medical Center Heliport     41.511398
# 25                    Shell Chemical East Site Heliport     30.191944
# 26                           Ac & R Components Heliport     39.665298
# 29                                Dow Chemical Heliport     43.949402
# 35                          Colgate-Piscataway Heliport     40.520901
# 39                       Miami Valley Hospital Heliport     39.745300
# 40                               Steel Systems Heliport     44.932899
# 41                                       R J D Heliport     39.948898
# 46                               Sw Region Faa Heliport     32.826900
# 47                       Tcjc-Northeast Campus Heliport     32.847599
# 59             Mountain View Regional Hospital Heliport     42.840361
# 62            Providence Seward Medical Center Heliport     60.105874
# 64              Community Hospital of De Queen Heliport     34.047298
# 65                                         Yat Heliport     34.608101
# 67                             Lugo Substation Heliport     34.368241
# 69     Los Angeles County Sheriff's Department Heliport     34.037800
# 70                 St Vincent General Hospital Heliport     39.245300
# 71                          Berlin Fairgrounds Heliport     41.627300
# 73                  Florida Hospital-Altamonte Heliport     28.666401
# 75                              Medical Center Heliport     32.479301
# 80       Hoopeston Community Memorial Hospital Heliport     40.458599
# 81                          Community Hospital Heliport     40.130901
# 86                            Lourdes Hospital Heliport     37.051701
# 90                              Compaq Andover Heliport     42.625099
# ...                                                 ...           ...
# 53051                           Parkes Hospital Helipad    -33.127030
# 53052                   Port Macquarie Hospital Helipad    -31.452683
# 53053                       Proserpine Hospital Helipad    -20.399120
# 53054                         Quirindi Hospital Helipad    -31.501070
# 53055                         Rylstone Hospital Helipad    -32.803975
# 53056                 Sydney Adventist Hospital Helipad    -33.733386
# 53057                            Scone Hospital Helipad    -32.050268
# 53058                        St George Hospital Helipad    -33.968070
# 53059                     Shellharbour Hospital Helipad    -34.559890
# 53060                        Singleton Hospital Helipad    -32.567080
# 53061                       Sutherland Hospital Helipad    -34.038783
# 53063            Tenterfield - Federation Park Heliport    -29.048000
# 53064          Trundle Hospital Helicopter Landing Site    -32.921700
# 53065                      Taree - Wrigley Park Helipad    -31.906400
# 53066                            Tumut Hospital Helipad    -35.308000
# 53067                         Tamworth Hospital Helipad    -31.074570
# 53068                Bulahdelah Helicopter Landing Site    -32.400000
# 53069                 Wagga - Duke of Kent Oval Helipad    -35.114340
# 53070                       Wollongong Hospital Helipad    -34.424190
# 53071                   Wellington-Rygate Park Heliport    -32.548700
# 53072                          Wee Waa Hospital Helipad    -30.225000
# 53073                            Wyong Hospital Helipad    -33.260250
# 53074                            Young Hospital Helipad    -34.320940
# 53083                               Yarra Bank Heliport    -37.822287
# 53161                         Pretoria Central Heliport    -25.655701
# 53257                                     Pumba Helipad    -33.387799
# 53259                                Cape Town Heliport    -33.901018
# 53280                         Kuruman Hospital Heliport    -27.459904
# 53370                                  Zamzama Heliport     26.710944
# 53628                                   Sealand Helipad     51.894444
#
#        longitude_deg  elevation_ft continent iso_country iso_region  \
# 0         -74.933601          11.0       NaN          US      US-PA
# 9        -116.459742        3350.0       NaN          US      US-CA
# 12        -82.345398          25.0       NaN          US      US-FL
# 15        -84.733902         957.0       NaN          US      US-GA
# 16       -155.980233          43.0       NaN          US      US-HI
# 19        -87.122803         600.0       NaN          US      US-IN
# 21        -87.260597         634.0       NaN          US      US-IN
# 25        -90.980833          15.0       NaN          US      US-LA
# 26        -89.705597         600.0       NaN          US      US-IL
# 29        -86.416702         588.0       NaN          US      US-MI
# 35        -74.474602          78.0       NaN          US      US-NJ
# 39        -84.187401         905.0       NaN          US      US-OH
# 40       -123.129997         195.0       NaN          US      US-OR
# 41        -75.746902         402.0       NaN          US      US-PA
# 46        -97.305801         598.0       NaN          US      US-TX
# 47        -97.189499         600.0       NaN          US      US-TX
# 59       -106.224443        5210.0       NaN          US      US-WY
# 62       -149.446249         120.0       NaN          US      US-AK
# 64        -94.354897         400.0       NaN          US      US-AR
# 65       -111.864998        3300.0       NaN          US      US-AZ
# 67       -117.370059        3733.0       NaN          US      US-CA
# 69       -118.153999         300.0       NaN          US      US-CA
# 70       -106.246002       10175.0       NaN          US      US-CO
# 71        -72.727501          60.0       NaN          US      US-CT
# 73        -81.370598          86.0       NaN          US      US-FL
# 75        -84.979103         319.0       NaN          US      US-GA
# 80        -87.659500         583.0       NaN          US      US-IL
# 81        -85.695801         890.0       NaN          US      US-IN
# 86        -88.646896         419.0       NaN          US      US-KY
# 90        -71.180099         140.0       NaN          US      US-MA
# ...              ...           ...       ...         ...        ...
# 53051     148.169990        1189.0        OC          AU     AU-NSW
# 53052     152.880760          32.0        OC          AU     AU-NSW
# 53053     148.585500          44.0        OC          AU     AU-QLD
# 53054     150.676606        1365.0        OC          AU     AU-NSW
# 53055     149.975076        1971.0        OC          AU     AU-NSW
# 53056     151.100006         584.0        OC          AU     AU-NSW
# 53057     150.877663         782.0        OC          AU     AU-NSW
# 53058     151.133680         150.0        OC          AU     AU-NSW
# 53059     150.841730          99.0        OC          AU     AU-NSW
# 53060     151.186865         151.0        OC          AU     AU-NSW
# 53061     151.115600         119.0        OC          AU     AU-NSW
# 53063     152.016400        2762.0        OC          AU     AU-NSW
# 53064     147.706700         822.0        OC          AU     AU-NSW
# 53065     152.450800          39.0        OC          AU     AU-NSW
# 53066     148.219100        1052.0        OC          AU     AU-NSW
# 53067     150.926410        1356.0        OC          AU     AU-NSW
# 53068     152.200000          13.0        OC          AU     AU-NSW
# 53069     147.354100         588.0        OC          AU     AU-NSW
# 53070     150.882200         160.0        OC          AU     AU-NSW
# 53071     148.949700        1005.0        OC          AU     AU-NSW
# 53072     149.448300         632.0        OC          AU     AU-NSW
# 53073     151.480690          94.0        OC          AU     AU-NSW
# 53074     148.287980        1523.0        OC          AU     AU-NSW
# 53083     144.956792           NaN        OC          AU     AU-VIC
# 53161      28.220600        4087.0        AF          ZA      ZA-GT
# 53257      26.410595           NaN        AF          ZA      ZA-EC
# 53259      18.425936           NaN        AF          ZA      ZA-WC
# 53280      23.443762           NaN        AF          ZA      ZA-NC
# 53370      67.667250         128.0        AS          PK      PK-SD
# 53628       1.482500          40.0        EU          GB     GB-ENG
#
#              municipality scheduled_service gps_code iata_code local_code  \
# 0                Bensalem                no      00A       NaN        00A
# 9             Pine Valley                no     00CN       NaN       00CN
# 12              Riverview                no     00FD       NaN       00FD
# 15                  Hiram                no     00GE       NaN       00GE
# 16            Kailua/Kona                no     00HI       NaN       00HI
# 19             Chesterton                no     00II       NaN       00II
# 21                 Hobart                no     00IN       NaN       00IN
# 25               Gonzales                no     00LA       NaN       00LA
# 26                Chatham                no     00LL       NaN       00LL
# 29              Ludington                no     00MI       NaN       00MI
# 35          New Brunswick                no     00NJ       NaN       00NJ
# 39                 Dayton                no     00OI       NaN       00OI
# 40                  Salem                no     00OR       NaN       00OR
# 41            Coatesville                no     00PA       NaN       00PA
# 46             Fort Worth                no     00TA       NaN       00TA
# 47             Fort Worth                no     00TE       NaN       00TE
# 59                 Casper                no     00WY       NaN       00WY
# 62                 Seward                no     01AK       NaN       01AK
# 64               De Queen                no     01AR       NaN       01AR
# 65             Camp Verde                no     01AZ       NaN       01AZ
# 67               Hesperia                no     01CA       NaN       01CA
# 69            Los Angeles                no     01CN       NaN       01CN
# 70              Leadville                no     01CO       NaN       01CO
# 71                 Berlin                no     01CT       NaN       01CT
# 73      Altamonte Springs                no     01FD       NaN       01FD
# 75               Columbus                no     01GA       NaN       01GA
# 80              Hoopeston                no     01IL       NaN       01IL
# 81               Anderson                no     01IN       NaN       01IN
# 86                Paducah                no     01KY       NaN       01KY
# 90                Andover                no     01MA       NaN       01MA
# ...                   ...               ...      ...       ...        ...
# 53051              Parkes                no     YXPK       NaN       YXPK
# 53052      Port Macquarie                no     YXPM       NaN       YXPM
# 53053          Proserpine                no     YXPN       NaN       YXPN
# 53054            Quirindi                no     YXQU       NaN       YXQU
# 53055            Rylstone                no     YXRN       NaN       YXRN
# 53056           Wahroonga                no     YXSA       NaN       YXSA
# 53057               Scone                no     YXSC       NaN       YXSC
# 53058             Kogarah                no     YXSG       NaN       YXSG
# 53059        Shellharbour                no     YXSH       NaN       YXSH
# 53060           Singleton                no     YXSI       NaN       YXSI
# 53061             Miranda                no     YXSU       NaN       YXSU
# 53063         Tenterfield                no     YXTE       NaN       YXTE
# 53064             Trundle                no     YXTN       NaN       YXTN
# 53065               Taree                no     YXTR       NaN       YXTR
# 53066               Tumut                no     YXTT       NaN       YXTT
# 53067            Tamworth                no     YXTW       NaN       YXTW
# 53068          Bulahdelah                no     YXUH       NaN       YXUH
# 53069               Wagga                no     YXWG       NaN       YXWG
# 53070          Wollongong                no     YXWL       NaN       YXWL
# 53071          Wellington                no     YXWT       NaN       YXWT
# 53072             Wee Waa                no     YXWW       NaN       YXWW
# 53073               Wyong                no     YXWY       NaN       YXWY
# 53074               Young                no     YXYO       NaN       YXYO
# 53083                 NaN                no     YYBK       NaN        NaN
# 53161            Pretoria                no      NaN       HPR        NaN
# 53257  Nelson Mandela Bay                no      NaN       NaN        NaN
# 53259                 NaN                no      NaN       NaN        NaN
# 53280             Kuruman                no      NaN       NaN        NaN
# 53370   Zamzama Gas Field                no      NaN       ZIZ        NaN
# 53628             Sealand                no      NaN       NaN        NaN
#
#                                          home_link  \
# 0                                              NaN
# 9                                              NaN
# 12                                             NaN
# 15                                             NaN
# 16                                             NaN
# 19                                             NaN
# 21                                             NaN
# 25                                             NaN
# 26                                             NaN
# 29                                             NaN
# 35                                             NaN
# 39                                             NaN
# 40                                             NaN
# 41                                             NaN
# 46                                             NaN
# 47                                             NaN
# 59                                             NaN
# 62                                             NaN
# 64                                             NaN
# 65                                             NaN
# 67                                             NaN
# 69                                             NaN
# 70                                             NaN
# 71                                             NaN
# 73                                             NaN
# 75                                             NaN
# 80                                             NaN
# 81                                             NaN
# 86                                             NaN
# 90                                             NaN
# ...                                            ...
# 53051                                          NaN
# 53052                                          NaN
# 53053                                          NaN
# 53054                                          NaN
# 53055                                          NaN
# 53056                                          NaN
# 53057                                          NaN
# 53058                                          NaN
# 53059                                          NaN
# 53060                                          NaN
# 53061                                          NaN
# 53063                                          NaN
# 53064                                          NaN
# 53065                                          NaN
# 53066                                          NaN
# 53067                                          NaN
# 53068                                          NaN
# 53069                                          NaN
# 53070                                          NaN
# 53071                                          NaN
# 53072                                          NaN
# 53073                                          NaN
# 53074                                          NaN
# 53083                                          NaN
# 53161                                          NaN
# 53257  http://www.pumbagamereserve.co.za/amenities
# 53259                                          NaN
# 53280                                          NaN
# 53370                                          NaN
# 53628                   http://www.sealandgov.org/
#
#                                           wikipedia_link              keywords
# 0                                                    NaN                   NaN
# 9                                                    NaN                   NaN
# 12                                                   NaN                   NaN
# 15                                                   NaN                   NaN
# 16                                                   NaN                   NaN
# 19                                                   NaN                   NaN
# 21                                                   NaN                   NaN
# 25                                                   NaN                   NaN
# 26                                                   NaN                   NaN
# 29                                                   NaN                   NaN
# 35                                                   NaN                   NaN
# 39                                                   NaN                   NaN
# 40                                                   NaN                   NaN
# 41                                                   NaN                   NaN
# 46                                                   NaN                   NaN
# 47                                                   NaN                   NaN
# 59                                                   NaN                   NaN
# 62                                                   NaN                   NaN
# 64                                                   NaN                   NaN
# 65                                                   NaN                   NaN
# 67                                                   NaN                   NaN
# 69                                                   NaN                   NaN
# 70                                                   NaN                   NaN
# 71                                                   NaN                   NaN
# 73                                                   NaN                   NaN
# 75                                                   NaN                   NaN
# 80                                                   NaN                   NaN
# 81                                                   NaN                   NaN
# 86                                                   NaN                   NaN
# 90                                                   NaN                   NaN
# ...                                                  ...                   ...
# 53051                                                NaN                   NaN
# 53052                                                NaN                   NaN
# 53053                                                NaN                   NaN
# 53054                                                NaN                   NaN
# 53055                                                NaN                   NaN
# 53056                                                NaN                   NaN
# 53057                                                NaN                   NaN
# 53058                                                NaN                   NaN
# 53059                                                NaN                   NaN
# 53060                                                NaN                   NaN
# 53061                                                NaN                   NaN
# 53063                                                NaN                   NaN
# 53064                                                NaN                   NaN
# 53065                                                NaN                   NaN
# 53066                                                NaN                   NaN
# 53067                                                NaN                   NaN
# 53068                                                NaN                   NaN
# 53069                                                NaN                   NaN
# 53070                                                NaN                   NaN
# 53071                                                NaN                   NaN
# 53072                                                NaN                   NaN
# 53073                                                NaN                   NaN
# 53074                                                NaN                   NaN
# 53083                                                NaN                   NaN
# 53161                                                NaN                   NaN
# 53257                                                NaN                   NaN
# 53259                                                NaN                   NaN
# 53280                                                NaN                   NaN
# 53370                                                NaN                   NaN
# 53628  http://en.wikipedia.org/wiki/Principality_of_S...  Roughs Tower Helipad
#
# [10581 rows x 18 columns]

# %% [markdown]
# ### SQL:
# select * from airports where type not in ('heliport', 'balloonport')

# %%
airports[~airports.type.isin(['heliport', 'balloonport'])]
# Out:
#            id    ident            type  \
# 1      323361     00AA   small_airport
# 2        6524     00AK   small_airport
# 3        6525     00AL   small_airport
# 4        6526     00AR          closed
# 5      322127     00AS   small_airport
# 6        6527     00AZ   small_airport
# 7        6528     00CA   small_airport
# 8      324424     00CL   small_airport
# 10       6529     00CO          closed
# 11       6531     00FA   small_airport
# 13       6533     00FL   small_airport
# 14       6534     00GA   small_airport
# 17       6537     00ID   small_airport
# 18     322581     00IG   small_airport
# 20       6539     00IL   small_airport
# 22       6541     00IS   small_airport
# 23       6542     00KS   small_airport
# 24       6543     00KY   small_airport
# 27       6545     00LS   small_airport
# 28       6546     00MD   small_airport
# 30       6548     00MN   small_airport
# 31       6549     00MO   small_airport
# 32       6550     00MT          closed
# 33       6551      00N   small_airport
# 34       6552     00NC   small_airport
# 36     321919     00NK   seaplane_base
# 37       6554     00NY   small_airport
# 38       6555     00OH   small_airport
# 42      45773     00PN   small_airport
# 43       6559     00PS          closed
# ...       ...      ...             ...
# 53600   32725     ZWYN   small_airport
# 53601   30646     ZYAS  medium_airport
# 53602   27237     ZYCC  medium_airport
# 53603  300858     ZYCH  medium_airport
# 53604   30827     ZYCY  medium_airport
# 53605  327349     ZYDU  medium_airport
# 53606  324338     ZYFX   small_airport
# 53607  313994     ZYFY  medium_airport
# 53608   27238     ZYHB   large_airport
# 53609   31576     ZYHE  medium_airport
# 53610   31701     ZYJL   small_airport
# 53611   27239     ZYJM  medium_airport
# 53612  327450     ZYJS  medium_airport
# 53613  313337     ZYJX  medium_airport
# 53614   31706     ZYJZ  medium_airport
# 53615  307012     ZYLD  medium_airport
# 53616  300516     ZYLS  medium_airport
# 53617   27240     ZYMD  medium_airport
# 53618  301193     ZYMH  medium_airport
# 53619   27241     ZYQQ  medium_airport
# 53620  327451     ZYSQ  medium_airport
# 53621  307017     ZYTH   small_airport
# 53622   27242     ZYTL   large_airport
# 53623  307013     ZYTN  medium_airport
# 53624   27243     ZYTX   large_airport
# 53625   27244     ZYYJ  medium_airport
# 53626  317861     ZYYK  medium_airport
# 53627   32753     ZYYY  medium_airport
# 53629  307326  ZZ-0002   small_airport
# 53630  313629     ZZZZ   small_airport
#
#                                            name  latitude_deg  longitude_deg  \
# 1                          Aero B Ranch Airport     38.704022    -101.473911
# 2                                  Lowell Field     59.949200    -151.695999
# 3                                  Epps Airpark     34.864799     -86.770302
# 4            Newport Hospital & Clinic Heliport     35.608700     -91.254898
# 5                                Fulton Airport     34.942803     -97.818019
# 6                                Cordes Airport     34.305599    -112.165001
# 7                       Goldstone /Gts/ Airport     35.350498    -116.888000
# 8                           Williams Ag Airport     39.427188    -121.763427
# 10                                   Cass Field     40.622202    -104.344002
# 11                          Grass Patch Airport     28.645500     -82.219002
# 13                            River Oak Airport     27.230900     -80.969200
# 14                             Lt World Airport     33.767502     -84.068298
# 17                         Delta Shores Airport     48.145302    -116.213997
# 18                                Goltl Airport     39.724028    -101.395994
# 20                               Hammer Airport     41.978401     -89.560402
# 22            Hayenga's Cant Find Farms Airport     40.025600     -89.122902
# 23                          Hayden Farm Airport     38.727798     -94.930496
# 24                        Robbins Roost Airport     37.409401     -84.619698
# 27                              Lejeune Airport     30.136299     -92.429398
# 28                                 Slater Field     38.757099     -75.753799
# 30                Battle Lake Municipal Airport     46.299999     -95.700302
# 31                Cooper Flying Service Airport     37.202801     -94.412399
# 32                          Sands Ranch Airport     48.537498    -109.705002
# 33                                Bucks Airport     39.473202     -75.185204
# 34                        North Raleigh Airport     36.085201     -78.371399
# 36                    Cliche Cove Seaplane Base     44.811861     -73.369806
# 37                               Weiss Airfield     42.900101     -77.499702
# 38                               Exit 3 Airport     41.590900     -84.142197
# 42                                Ferrell Field     41.299500     -80.211111
# 43                                 Thomas Field     40.377800     -77.365303
# ...                                         ...           ...            ...
# 53600                            Yining Airport     43.955799      81.330299
# 53601                           Anshan Air Base     41.105301     122.853996
# 53602                           Longjia Airport     43.996201     125.684998
# 53603                          Changhai Airport     39.266667     122.666944
# 53604                          Chaoyang Airport     41.538101     120.434998
# 53605                  Wudalianchi Dedu Airport     48.445000     126.133000
# 53606                             Fuxin Airport     42.069014     121.718122
# 53607                             Dongji Aiport     48.199494     134.366447
# 53608                           Taiping Airport     45.623402     126.250000
# 53609                             Heihe Airport     50.171621     127.308884
# 53610                             Jilin Airport     44.002201     126.396004
# 53611                           Jiamusi Airport     46.843399     130.464996
# 53612                      Jiansanjiang Airport     47.110000     132.660278
# 53613                    Jixi Xingkaihu Airport     45.293000     131.193000
# 53614                           Jinzhou Airport     41.101398     121.061996
# 53615                             Lindu Airport     47.752056     129.019125
# 53616                      Yushu Batang Airport     32.836389      97.036389
# 53617  Mudanjiang Hailang International Airport     44.524101     129.569000
# 53618                           Gu-Lian Airport     52.912778     122.430000
# 53619                  Qiqihar Sanjiazi Airport     47.239601     123.917999
# 53620                 Songyuan Chaganhu Airport     44.938114     124.550178
# 53621                              Tahe Airport     52.224444     124.720222
# 53622                        Zhoushuizi Airport     38.965698     121.539001
# 53623                 Tonghua Sanyuanpu Airport     42.253889     125.703333
# 53624                           Taoxian Airport     41.639801     123.483002
# 53625               Yanji Chaoyangchuan Airport     42.882801     129.451004
# 53626                     Yingkou Lanqi Airport     40.542524     122.358600
# 53627                   Shenyang Dongta Airport     41.784401     123.496002
# 53629                 Glorioso Islands Airstrip    -11.584278      47.296389
# 53630                    Satsuma Iōjima Airport     30.784722     130.270556
#
#        elevation_ft continent iso_country iso_region  \
# 1            3435.0       NaN          US      US-KS
# 2             450.0       NaN          US      US-AK
# 3             820.0       NaN          US      US-AL
# 4             237.0       NaN          US      US-AR
# 5            1100.0       NaN          US      US-OK
# 6            3810.0       NaN          US      US-AZ
# 7            3038.0       NaN          US      US-CA
# 8              87.0       NaN          US      US-CA
# 10           4830.0       NaN          US      US-CO
# 11             53.0       NaN          US      US-FL
# 13             35.0       NaN          US      US-FL
# 14            700.0       NaN          US      US-GA
# 17           2064.0       NaN          US      US-ID
# 18           3359.0       NaN          US      US-KS
# 20            840.0       NaN          US      US-IL
# 22            820.0       NaN          US      US-IL
# 23           1100.0       NaN          US      US-KS
# 24           1265.0       NaN          US      US-KY
# 27             12.0       NaN          US      US-LA
# 28             45.0       NaN          US      US-MD
# 30           1365.0       NaN          US      US-MN
# 31            970.0       NaN          US      US-MO
# 32           2600.0       NaN          US      US-MT
# 33            105.0       NaN          US      US-NJ
# 34            348.0       NaN          US      US-NC
# 36             96.0       NaN          US      US-NY
# 37           1000.0       NaN          US      US-NY
# 38            785.0       NaN          US      US-OH
# 42           1301.0       NaN          US      US-PA
# 43            815.0       NaN          US      US-PA
# ...             ...       ...         ...        ...
# 53600           NaN        AS          CN      CN-65
# 53601           NaN        AS          CN      CN-21
# 53602         706.0        AS          CN      CN-22
# 53603          80.0        AS          CN      CN-21
# 53604         568.0        AS          CN      CN-21
# 53605         984.0        AS          CN      CN-23
# 53606         548.0        AS          CN      CN-21
# 53607           NaN        AS          CN      CN-23
# 53608         457.0        AS          CN      CN-23
# 53609        8530.0        AS          CN      CN-23
# 53610           NaN        AS          CN      CN-22
# 53611         262.0        AS          CN      CN-23
# 53612           NaN        AS          CN      CN-23
# 53613         760.0        AS          CN      CN-23
# 53614           NaN        AS          CN      CN-21
# 53615         791.0        AS          CN      CN-23
# 53616       12816.0        AS          CN      CN-63
# 53617         883.0        AS          CN      CN-23
# 53618        1836.0        AS          CN      CN-23
# 53619         477.0        AS          CN      CN-23
# 53620         459.0        AS          CN      CN-22
# 53621        1240.0        AS          CN      CN-23
# 53622         107.0        AS          CN      CN-21
# 53623        1200.0        AS          CN      CN-22
# 53624         198.0        AS          CN      CN-21
# 53625         624.0        AS          CN      CN-22
# 53626           0.0        AS          CN      CN-21
# 53627           NaN        AS          CN      CN-21
# 53629          11.0        AF          TF     TF-U-A
# 53630         338.0        AS          JP      JP-46
#
#                                municipality scheduled_service gps_code  \
# 1                                     Leoti                no     00AA
# 2                              Anchor Point                no     00AK
# 3                                   Harvest                no     00AL
# 4                                   Newport                no      NaN
# 5                                      Alex                no     00AS
# 6                                    Cordes                no     00AZ
# 7                                   Barstow                no     00CA
# 8                                     Biggs                no     00CL
# 10                               Briggsdale                no      NaN
# 11                                 Bushnell                no     00FA
# 13                               Okeechobee                no     00FL
# 14                                 Lithonia                no     00GA
# 17                               Clark Fork                no     00ID
# 18                                 McDonald                no     00IG
# 20                                     Polo                no     00IL
# 22                                    Kings                no     00IS
# 23                                  Gardner                no     00KS
# 24                                 Stanford                no     00KY
# 27                                Esterwood                no     00LS
# 28                             Federalsburg                no     00MD
# 30                              Battle Lake                no     00MN
# 31                                     Alba                no     00MO
# 32                                    Havre                no      NaN
# 33                                Bridgeton                no      00N
# 34                                Louisburg                no     00NC
# 36                              Beekmantown                no     00NK
# 37                          West Bloomfield                no     00NY
# 38                                  Wauseon                no     00OH
# 42                                   Mercer                no     00PN
# 43                                Loysville                no      NaN
# ...                                     ...               ...      ...
# 53600                                Yining               yes     ZWYN
# 53601                                Anshan               yes     ZYAS
# 53602                             Changchun               yes     ZYCC
# 53603                              Changhai                no     ZYCH
# 53604                              Chaoyang               yes     ZYCY
# 53605                           Wudalianchi               yes     ZYDU
# 53606                                 Fuxin                no     ZYFX
# 53607                                Fuyuan               yes     ZYFY
# 53608                                Harbin               yes     ZYHB
# 53609                                 Heihe               yes     ZYHE
# 53610                                 Jilin                no     ZYJL
# 53611                               Jiamusi               yes     ZYJM
# 53612                          Jiansanjiang               yes     ZYJS
# 53613                                  Jixi               yes     ZYJX
# 53614                               Jinzhou               yes     ZYJZ
# 53615                                Yichun               yes     ZYLD
# 53616                                 Yushu                no     ZYLS
# 53617                            Mudanjiang               yes     ZYMD
# 53618                                  Mohe               yes     ZYMH
# 53619                               Qiqihar               yes     ZYQQ
# 53620  Qian Gorlos Mongol Autonomous County               yes     ZYSQ
# 53621                                  Tahe                no     ZYTH
# 53622                                Dalian               yes     ZYTL
# 53623                               Tonghua               yes     ZYTN
# 53624                              Shenyang               yes     ZYTX
# 53625                                 Yanji               yes     ZYYJ
# 53626                               Yingkou               yes     ZYYK
# 53627                              Shenyang                no     ZYYY
# 53629                      Grande Glorieuse                no      NaN
# 53630                          Mishima-Mura                no     RJX7
#
#       iata_code local_code home_link  \
# 1           NaN       00AA       NaN
# 2           NaN       00AK       NaN
# 3           NaN       00AL       NaN
# 4           NaN        NaN       NaN
# 5           NaN       00AS       NaN
# 6           NaN       00AZ       NaN
# 7           NaN       00CA       NaN
# 8           NaN       00CL       NaN
# 10          NaN        NaN       NaN
# 11          NaN       00FA       NaN
# 13          NaN       00FL       NaN
# 14          NaN       00GA       NaN
# 17          NaN       00ID       NaN
# 18          NaN       00IG       NaN
# 20          NaN       00IL       NaN
# 22          NaN       00IS       NaN
# 23          NaN       00KS       NaN
# 24          NaN       00KY       NaN
# 27          NaN       00LS       NaN
# 28          NaN       00MD       NaN
# 30          NaN       00MN       NaN
# 31          NaN       00MO       NaN
# 32          NaN        NaN       NaN
# 33          NaN        00N       NaN
# 34          NaN       00NC       NaN
# 36          NaN       00NK       NaN
# 37          NaN       00NY       NaN
# 38          NaN       00OH       NaN
# 42          NaN       00PN       NaN
# 43          NaN        NaN       NaN
# ...         ...        ...       ...
# 53600       YIN        NaN       NaN
# 53601       AOG        NaN       NaN
# 53602       CGQ        NaN       NaN
# 53603       CNI        NaN       NaN
# 53604       CHG        NaN       NaN
# 53605       DTU        NaN       NaN
# 53606       NaN        NaN       NaN
# 53607       FYJ        NaN       NaN
# 53608       HRB        NaN       NaN
# 53609       HEK        NaN       NaN
# 53610       JIL        NaN       NaN
# 53611       JMU        NaN       NaN
# 53612       JSJ        NaN       NaN
# 53613       JXA        NaN       NaN
# 53614       JNZ        NaN       NaN
# 53615       LDS        NaN       NaN
# 53616       YUS        NaN       NaN
# 53617       MDG        NaN       NaN
# 53618       OHE        NaN       NaN
# 53619       NDG        NaN       NaN
# 53620       YSQ        NaN       NaN
# 53621       NaN        NaN       NaN
# 53622       DLC        NaN       NaN
# 53623       TNH        NaN       NaN
# 53624       SHE        NaN       NaN
# 53625       YNJ        NaN       NaN
# 53626       YKH        NaN       NaN
# 53627       NaN        NaN       NaN
# 53629       NaN        NaN       NaN
# 53630       NaN        NaN       NaN
#
#                                           wikipedia_link  \
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 20                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 30                                                   NaN
# 31                                                   NaN
# 32                                                   NaN
# 33                                                   NaN
# 34                                                   NaN
# 36                                                   NaN
# 37                                                   NaN
# 38                                                   NaN
# 42                                                   NaN
# 43                                                   NaN
# ...                                                  ...
# 53600       https://en.wikipedia.org/wiki/Yining_Airport
# 53601  https://en.wikipedia.org/wiki/Anshan_Teng%27ao...
# 53602  http://en.wikipedia.org/wiki/Changchun_Longjia...
# 53603      http://en.wikipedia.org/wiki/Changhai_Airport
# 53604     https://en.wikipedia.org/wiki/Chaoyang_Airport
# 53605  https://en.wikipedia.org/wiki/Wudalianchi_Dedu...
# 53606                                                NaN
# 53607  https://en.wikipedia.org/wiki/Fuyuan_Dongji_Ai...
# 53608  http://en.wikipedia.org/wiki/Harbin_Taiping_In...
# 53609         http://en.wikipedia.org/wiki/Heihe_Airport
# 53610  https://en.wikipedia.org/wiki/Jilin_Ertaizi_Ai...
# 53611       http://en.wikipedia.org/wiki/Jiamusi_Airport
# 53612  https://en.wikipedia.org/wiki/Jiansanjiang_Air...
# 53613  http://en.wikipedia.org/wiki/Jixi_Xingkaihu_Ai...
# 53614       http://en.wikipedia.org/wiki/Jinzhou_Airport
# 53615  http://en.wikipedia.org/wiki/Yichun_Lindu_Airport
# 53616  http://en.wikipedia.org/wiki/Yushu_Batang_Airport
# 53617    http://en.wikipedia.org/wiki/Mudanjiang_Airport
# 53618   http://en.wikipedia.org/wiki/Mohe_Gulian_Airport
# 53619       http://en.wikipedia.org/wiki/Qiqihar_Airport
# 53620  https://en.wikipedia.org/wiki/Songyuan_Chaganh...
# 53621                                                NaN
# 53622  http://en.wikipedia.org/wiki/Dalian_Zhoushuizi...
# 53623  http://en.wikipedia.org/wiki/Tonghua_Sanyuanpu...
# 53624  http://en.wikipedia.org/wiki/Shenyang_Taoxian_...
# 53625  http://en.wikipedia.org/wiki/Yanji_Chaoyangchu...
# 53626  https://en.wikipedia.org/wiki/Yingkou_Lanqi_Ai...
# 53627                                                NaN
# 53629                                                NaN
# 53630  http://wikimapia.org/6705190/Satsuma-Iwo-jima-...
#
#                     keywords
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                       00AR
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 10                      00CO
# 11                       NaN
# 13                       NaN
# 14                       NaN
# 17                       NaN
# 18                       NaN
# 20                       NaN
# 22                       NaN
# 23                       NaN
# 24                       NaN
# 27                       NaN
# 28                       NaN
# 30                       NaN
# 31                       5K8
# 32                      00MT
# 33                       NaN
# 34                       NaN
# 36                       NaN
# 37                       NaN
# 38                       NaN
# 42                       NaN
# 43                      00PS
# ...                      ...
# 53600                    NaN
# 53601                    NaN
# 53602                    NaN
# 53603                    NaN
# 53604                    NaN
# 53605                    NaN
# 53606                    NaN
# 53607                    NaN
# 53608                    NaN
# 53609                    NaN
# 53610                    NaN
# 53611                    NaN
# 53612                    NaN
# 53613                    NaN
# 53614    Xiaolingzi Air Base
# 53615     Yichun Shi Airport
# 53616                    NaN
# 53617             Mudanjiang
# 53618                    NaN
# 53619                    NaN
# 53620                    NaN
# 53621                    NaN
# 53622        Dalian Air Base
# 53623  Tonghua Liuhe Airport
# 53624                    NaN
# 53625                    NaN
# 53626                    NaN
# 53627                    NaN
# 53629                    NaN
# 53630   SATSUMA,IWOJIMA,RJX7
#
# [43050 rows x 18 columns]

# %% [markdown]
# ##
#
#
# ## GROUP BY, COUNT, ORDER BY
#
# Grouping is straightforward: use the $.groupby()$ operator. There’s a subtle difference between semantics of a COUNT in SQL and Pandas. In Pandas, .count() will return the number of non-null/NaN values. To get the same result as the SQL COUNT, use .size().

# %% [markdown]
# ### SQL:
# select iso_country, type, count(*) from airports group by iso_country, type order by iso_country, type

# %%
airports.groupby(['iso_country', 'type']).size()
# Out:
# iso_country  type
# AD           heliport            2
# AE           closed              3
#              heliport           21
#              large_airport       4
#              medium_airport      7
#              seaplane_base       3
#              small_airport      15
# AF           closed              1
#              heliport            3
#              medium_airport      8
#              small_airport      51
# AG           medium_airport      1
#              small_airport       2
# AI           medium_airport      1
# AL           closed              4
#              heliport            2
#              large_airport       1
#              medium_airport      3
#              small_airport       2
# AM           closed              4
#              large_airport       1
#              medium_airport      3
#              small_airport       5
# AO           closed             10
#              medium_airport     21
#              small_airport      73
# AQ           closed              2
#              medium_airport      4
#              small_airport      20
# AR           balloonport         1
#                               ...
# VI           seaplane_base       3
# VN           closed              6
#              heliport            5
#              large_airport       3
#              medium_airport     17
#              small_airport      17
# VU           medium_airport      4
#              small_airport      28
# WF           medium_airport      2
# WS           medium_airport      1
#              small_airport       3
# XK           closed              2
#              heliport            2
#              large_airport       1
#              medium_airport      1
# YE           medium_airport     11
#              small_airport      14
# YT           medium_airport      1
# ZA           closed             12
#              heliport            4
#              large_airport       5
#              medium_airport     56
#              small_airport     407
# ZM           closed              1
#              large_airport       1
#              medium_airport      7
#              small_airport      94
# ZW           closed              1
#              medium_airport      9
#              small_airport     126
# Length: 815, dtype: int64

# %% [markdown]
# ### SQL:
#
# select iso_country, type, count(\*) from airports group by iso_country, type order by iso_country, count(*) desc

# %%
type(airports.groupby(['iso_country', 'type']).size())
# Out:
# pandas.core.series.Series

# %%
type(airports.groupby(['iso_country', 'type']).size().to_frame('size'))
# Out:
# pandas.core.frame.DataFrame

# %%
airports.groupby(['iso_country', 'type']).size()
# Out:
# iso_country  type
# AD           heliport            2
# AE           closed              3
#              heliport           21
#              large_airport       4
#              medium_airport      7
#              seaplane_base       3
#              small_airport      15
# AF           closed              1
#              heliport            3
#              medium_airport      8
#              small_airport      51
# AG           medium_airport      1
#              small_airport       2
# AI           medium_airport      1
# AL           closed              4
#              heliport            2
#              large_airport       1
#              medium_airport      3
#              small_airport       2
# AM           closed              4
#              large_airport       1
#              medium_airport      3
#              small_airport       5
# AO           closed             10
#              medium_airport     21
#              small_airport      73
# AQ           closed              2
#              medium_airport      4
#              small_airport      20
# AR           balloonport         1
#                               ...
# VI           seaplane_base       3
# VN           closed              6
#              heliport            5
#              large_airport       3
#              medium_airport     17
#              small_airport      17
# VU           medium_airport      4
#              small_airport      28
# WF           medium_airport      2
# WS           medium_airport      1
#              small_airport       3
# XK           closed              2
#              heliport            2
#              large_airport       1
#              medium_airport      1
# YE           medium_airport     11
#              small_airport      14
# YT           medium_airport      1
# ZA           closed             12
#              heliport            4
#              large_airport       5
#              medium_airport     56
#              small_airport     407
# ZM           closed              1
#              large_airport       1
#              medium_airport      7
#              small_airport      94
# ZW           closed              1
#              medium_airport      9
#              small_airport     126
# Length: 815, dtype: int64

# %%
airports.groupby(['iso_country', 'type']).size().to_frame('size')
# Out:
#                             size
# iso_country type
# AD          heliport           2
# AE          closed             3
#             heliport          21
#             large_airport      4
#             medium_airport     7
#             seaplane_base      3
#             small_airport     15
# AF          closed             1
#             heliport           3
#             medium_airport     8
#             small_airport     51
# AG          medium_airport     1
#             small_airport      2
# AI          medium_airport     1
# AL          closed             4
#             heliport           2
#             large_airport      1
#             medium_airport     3
#             small_airport      2
# AM          closed             4
#             large_airport      1
#             medium_airport     3
#             small_airport      5
# AO          closed            10
#             medium_airport    21
#             small_airport     73
# AQ          closed             2
#             medium_airport     4
#             small_airport     20
# AR          balloonport        1
# ...                          ...
# VI          seaplane_base      3
# VN          closed             6
#             heliport           5
#             large_airport      3
#             medium_airport    17
#             small_airport     17
# VU          medium_airport     4
#             small_airport     28
# WF          medium_airport     2
# WS          medium_airport     1
#             small_airport      3
# XK          closed             2
#             heliport           2
#             large_airport      1
#             medium_airport     1
# YE          medium_airport    11
#             small_airport     14
# YT          medium_airport     1
# ZA          closed            12
#             heliport           4
#             large_airport      5
#             medium_airport    56
#             small_airport    407
# ZM          closed             1
#             large_airport      1
#             medium_airport     7
#             small_airport     94
# ZW          closed             1
#             medium_airport     9
#             small_airport    126
#
# [815 rows x 1 columns]

# %%
airports.groupby(['iso_country', 'type']).size().to_frame('size').reset_index()
# Out:
#     iso_country            type  size
# 0            AD        heliport     2
# 1            AE          closed     3
# 2            AE        heliport    21
# 3            AE   large_airport     4
# 4            AE  medium_airport     7
# 5            AE   seaplane_base     3
# 6            AE   small_airport    15
# 7            AF          closed     1
# 8            AF        heliport     3
# 9            AF  medium_airport     8
# 10           AF   small_airport    51
# 11           AG  medium_airport     1
# 12           AG   small_airport     2
# 13           AI  medium_airport     1
# 14           AL          closed     4
# 15           AL        heliport     2
# 16           AL   large_airport     1
# 17           AL  medium_airport     3
# 18           AL   small_airport     2
# 19           AM          closed     4
# 20           AM   large_airport     1
# 21           AM  medium_airport     3
# 22           AM   small_airport     5
# 23           AO          closed    10
# 24           AO  medium_airport    21
# 25           AO   small_airport    73
# 26           AQ          closed     2
# 27           AQ  medium_airport     4
# 28           AQ   small_airport    20
# 29           AR     balloonport     1
# ..          ...             ...   ...
# 785          VI   seaplane_base     3
# 786          VN          closed     6
# 787          VN        heliport     5
# 788          VN   large_airport     3
# 789          VN  medium_airport    17
# 790          VN   small_airport    17
# 791          VU  medium_airport     4
# 792          VU   small_airport    28
# 793          WF  medium_airport     2
# 794          WS  medium_airport     1
# 795          WS   small_airport     3
# 796          XK          closed     2
# 797          XK        heliport     2
# 798          XK   large_airport     1
# 799          XK  medium_airport     1
# 800          YE  medium_airport    11
# 801          YE   small_airport    14
# 802          YT  medium_airport     1
# 803          ZA          closed    12
# 804          ZA        heliport     4
# 805          ZA   large_airport     5
# 806          ZA  medium_airport    56
# 807          ZA   small_airport   407
# 808          ZM          closed     1
# 809          ZM   large_airport     1
# 810          ZM  medium_airport     7
# 811          ZM   small_airport    94
# 812          ZW          closed     1
# 813          ZW  medium_airport     9
# 814          ZW   small_airport   126
#
# [815 rows x 3 columns]

# %%
airports.groupby(['iso_country', 'type']).size().to_frame('size').reset_index().sort_values(['iso_country', 'size'], ascending=[True, False])
# Out:
#     iso_country            type  size
# 0            AD        heliport     2
# 2            AE        heliport    21
# 6            AE   small_airport    15
# 4            AE  medium_airport     7
# 3            AE   large_airport     4
# 1            AE          closed     3
# 5            AE   seaplane_base     3
# 10           AF   small_airport    51
# 9            AF  medium_airport     8
# 8            AF        heliport     3
# 7            AF          closed     1
# 12           AG   small_airport     2
# 11           AG  medium_airport     1
# 13           AI  medium_airport     1
# 14           AL          closed     4
# 17           AL  medium_airport     3
# 15           AL        heliport     2
# 18           AL   small_airport     2
# 16           AL   large_airport     1
# 22           AM   small_airport     5
# 19           AM          closed     4
# 21           AM  medium_airport     3
# 20           AM   large_airport     1
# 25           AO   small_airport    73
# 24           AO  medium_airport    21
# 23           AO          closed    10
# 28           AQ   small_airport    20
# 27           AQ  medium_airport     4
# 26           AQ          closed     2
# 34           AR   small_airport   618
# ..          ...             ...   ...
# 784          VI  medium_airport     2
# 789          VN  medium_airport    17
# 790          VN   small_airport    17
# 786          VN          closed     6
# 787          VN        heliport     5
# 788          VN   large_airport     3
# 792          VU   small_airport    28
# 791          VU  medium_airport     4
# 793          WF  medium_airport     2
# 795          WS   small_airport     3
# 794          WS  medium_airport     1
# 796          XK          closed     2
# 797          XK        heliport     2
# 798          XK   large_airport     1
# 799          XK  medium_airport     1
# 801          YE   small_airport    14
# 800          YE  medium_airport    11
# 802          YT  medium_airport     1
# 807          ZA   small_airport   407
# 806          ZA  medium_airport    56
# 803          ZA          closed    12
# 805          ZA   large_airport     5
# 804          ZA        heliport     4
# 811          ZM   small_airport    94
# 810          ZM  medium_airport     7
# 808          ZM          closed     1
# 809          ZM   large_airport     1
# 814          ZW   small_airport   126
# 813          ZW  medium_airport     9
# 812          ZW          closed     1
#
# [815 rows x 3 columns]

# %% [markdown]
# ##
#
#
#
#
# ## HAVING

# %% [markdown]
# ### SQL:
# select type, count(\*) from airports where iso_country = 'US' group by type having count(\*) > 1000 order by count(*) desc

# %%
airports_tmp = airports[airports.iso_country == 'US'].groupby('type').size().to_frame('size').reset_index()

# %%
airports_tmp[airports_tmp['size'] > 1000].sort_values('size', ascending=False)
# Out:
#             type   size
# 6  small_airport  13834
# 2       heliport   6243

# %% [markdown]
# ### a better method, using filter()

# %%
airports[airports.iso_country == 'US'].groupby('type').filter(lambda g: len(g)>1000).groupby('type').size().sort_values(ascending=False).to_frame('size').reset_index()
# Out:
#             type   size
# 0  small_airport  13834
# 1       heliport   6243

# %% [markdown]
# ##
#
#
# ## Top N records
#
#
# Let’s say we did some preliminary querying, and now have a dataframe called **by_country**, that contains the number of airports per country:

# %%
by_country = airports.groupby('iso_country').size().to_frame('airport_count').reset_index()

# %%
by_country.head(3)
# Out:
#   iso_country  airport_count
# 0          AD              2
# 1          AE             53
# 2          AF             63

# %% [markdown]
# In the next example, we order things by ***airport_count*** and only select the top 10 countries with the largest count. Second example is the more complicated case, in which we want “the next 10 after the top 10”:

# %% [markdown]
# ### SQL:
# select iso_country from by_country order by size desc limit 10

# %%
by_country.nlargest(10,columns='airport_count')
# Out:
#     iso_country  airport_count
# 224          US          22455
# 29           BR           4248
# 35           CA           2781
# 12           AU           1965
# 184          RU           1030
# 54           DE            937
# 74           GB            884
# 117          KR            881
# 152          MX            847
# 9            AR            842

# %% [markdown]
# ### SQL:
# select iso_country from by_country order by size desc limit 10 offset 10

# %%
by_country.nlargest(20, columns='airport_count').tail(10)
# Out:
#     iso_country  airport_count
# 72           FR            841
# 46           CO            706
# 105          IT            668
# 229          VE            592
# 170          PG            591
# 239          ZA            484
# 43           CL            474
# 96           ID            466
# 65           ES            409
# 45           CN            399

# %%
by_country.nlargest(20, columns='airport_count')[10:]
# Out:
#     iso_country  airport_count
# 72           FR            841
# 46           CO            706
# 105          IT            668
# 229          VE            592
# 170          PG            591
# 239          ZA            484
# 43           CL            474
# 96           ID            466
# 65           ES            409
# 45           CN            399

# %% [markdown]
# ##
#
#
#
# ## Aggregate functions (MIN, MAX, MEAN)

# %% [markdown]
# ### SQL:
# select max(length_ft), min(length_ft), mean(length_ft), median(length_ft) from runways

# %%
runways.head(3)
# Out:
#        id  airport_ref airport_ident  length_ft  width_ft surface  lighted  \
# 0  269408         6523           00A       80.0      80.0  ASPH-G        1
# 1  255155         6524          00AK     2500.0      70.0    GRVL        0
# 2  254165         6525          00AL     2300.0     200.0    TURF        0
#
#    closed le_ident  le_latitude_deg     ...       le_elevation_ft  \
# 0       0       H1              NaN     ...                   NaN
# 1       0        N              NaN     ...                   NaN
# 2       0       01              NaN     ...                   NaN
#
#    le_heading_degT  le_displaced_threshold_ft  he_ident he_latitude_deg  \
# 0              NaN                        NaN       NaN             NaN
# 1              NaN                        NaN         S             NaN
# 2              NaN                        NaN        19             NaN
#
#    he_longitude_deg  he_elevation_ft  he_heading_degT  \
# 0               NaN              NaN              NaN
# 1               NaN              NaN              NaN
# 2               NaN              NaN              NaN
#
#    he_displaced_threshold_ft  Unnamed: 20
# 0                        NaN          NaN
# 1                        NaN          NaN
# 2                        NaN          NaN
#
# [3 rows x 21 columns]

# %%
runways.agg({'length_ft': ['min', 'max', 'mean', 'median']}).T
# Out:
#            min       max         mean  median
# length_ft  0.0  120000.0  3263.080516  2754.0

# %% [markdown]
# ##
#
#
#
# ## JOIN

# %% [markdown]
# ### SQL:
# select airport_ident, type, description, frequency_mhz from airport_freq join airports on airport_freq.airport_ref = airports.id where airports.ident = 'KLAX'

# %%
airport_freq.merge(airports[airports.ident == 'KLAX'][['id']], left_on = 'airport_ref', right_on ='id', how='inner')[['airport_ident', 'type', 'description', 'frequency_mhz']]
# Out:
#    airport_ident  type description  frequency_mhz
# 0           KLAX   APP   SOCAL APP          36.07
# 1           KLAX   APP   SOCAL APP         124.30
# 2           KLAX  ATIS        ATIS         133.80
# 3           KLAX   CLD    CLNC DEL         121.40
# 4           KLAX   DEP   SOCAL DEP         124.30
# 5           KLAX   GND         GND         121.65
# 6           KLAX  MISC          CG          34.50
# 7           KLAX  MISC          CG         898.40
# 8           KLAX   OPS          AF          37.22
# 9           KLAX   TWR         TWR         119.80
# 10          KLAX  UNIC      UNICOM         122.95

# %% [markdown]
# ##
#
#
#
# ##
# ## UNION ALL and UNION

# %% [markdown]
# select name, municipality from airports where ident = 'KLAX' union all select name, municipality from airports where ident = 'KLGB'

# %%
df1 = airports.loc[airports.ident == 'KLAX', ['name', 'municipality']]

# %%
df2 = airports.loc[airports.ident == 'KLGB', ['name', 'municipality']]

# %%
pd.concat([df1, df2], axis=0)
# Out:
#                                        name municipality
# 27524     Los Angeles International Airport  Los Angeles
# 27549  Long Beach /Daugherty Field/ Airport   Long Beach

# %% [markdown]
# ##
#
#
# ##
#
#
# ## INSERT
#
# There’s no such thing as an **INSERT** in Pandas. Instead, you would create a new dataframe containing new records, and then concat the two:

# %% [markdown]
# create table heroes (id integer, name text);
#
# insert into heroes values (1, 'Harry Potter');
#
# insert into heroes values (2, 'Ron Weasley');
#
# insert into heroes values (3, 'Hermione Granger');

# %%
df1 = pd.DataFrame({'id': [1, 2], 'name': ['Harry Potter', 'Ron Weasley']})

df2 = pd.DataFrame({'id': [3], 'name': ['Hermione Granger']})

# %%
pd.concat([df1, df2]).reset_index(drop=True)
# Out:
#    id              name
# 0   1      Harry Potter
# 1   2       Ron Weasley
# 2   3  Hermione Granger

# %% [markdown]
# ##
#
# ##
#
# ## UPDATE

# %% [markdown]
# update airports set home_link = 'http://www.lawa.org/welcomelax.aspx' where ident == 'KLAX'

# %%
airports.loc[airports.ident == 'KLAX', 'home_link'] = 'http://www.lawa.org/welcomelax.aspx'

# %%
airports[airports.ident == 'KLAX']
# Out:
#          id ident           type                               name  \
# 27524  3632  KLAX  large_airport  Los Angeles International Airport
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 27524     33.942501    -118.407997         125.0       NaN          US
#
#       iso_region municipality scheduled_service gps_code iata_code local_code  \
# 27524      US-CA  Los Angeles               yes     KLAX       LAX        LAX
#
#                                  home_link  \
# 27524  http://www.lawa.org/welcomelax.aspx
#
#                                           wikipedia_link keywords
# 27524  http://en.wikipedia.org/wiki/Los_Angeles_Inter...      NaN

# %% [markdown]
# ##
#
#
# ##
#
# ## DELETE
#
#
# The easiest (and the most readable) way to “delete” things from a Pandas dataframe is to subset the dataframe to rows you want to keep. Alternatively, you can get the indices of rows to delete, and **.drop()** rows using those indices:

# %% [markdown]
# delete from lax_freq where type = 'MISC'

# %% [markdown]
# ### Pandas:
#
# lax_freq = lax_freq[lax_freq.type != 'MISC']
#
# lax_freq.drop(lax_freq[lax_freq.type == 'MISC'].index)
